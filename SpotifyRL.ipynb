# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip cache purge
# Out:
# WARNING: No matching packages
# Files removed: 0

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/spotify_dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
df.describe()
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
df['track_genre'].unique()
# Out:
# array(['acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient',
#        'anime', 'black-metal', 'bluegrass', 'blues', 'brazil',
#        'breakbeat', 'british', 'cantopop', 'chicago-house', 'children',
#        'chill', 'classical', 'club', 'comedy', 'country', 'dance',
#        'dancehall', 'death-metal', 'deep-house', 'detroit-techno',
#        'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm',
#        'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk',
#        'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove',
#        'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle',
#        'heavy-metal', 'hip-hop', 'honky-tonk', 'house', 'idm', 'indian',
#        'indie-pop', 'indie', 'industrial', 'iranian', 'j-dance', 'j-idol',
#        'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino',
#        'malay', 'mandopop', 'metal', 'metalcore', 'minimal-techno', 'mpb',
# ...

# %%
df['duration_ms'].value_counts()
# Out:
# duration_ms
# 162897    146
# 180000    104
# 192000     91
# 240000     84
# 118840     76
#          ...
# 196570      1
# 252474      1
# 224135      1
# 214396      1
# 106909      1
# Name: count, Length: 50697, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df['popularity'], bins=30, kde=False)
plt.xlabel('Popularity', size=12)
plt.ylabel('Number of Tracks', size=12)
plt.title('Distribution showing Popular Tracks', size=12)
plt.xticks(size=12)
plt.show()

# %%
sns.histplot(df['duration_ms'], bins=30, kde=False)
plt.xlabel('Duration (ms)', size=12)
plt.ylabel('Number of Tracks', size=12)
plt.title('Distribution of Track Durations', size=12)
plt.xticks(size=12)
plt.show()

# %%
sns.countplot(x='explicit', data=df)
plt.title('Track Distribution by Explicitness')
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df['danceability'], bins=30, kde=False)
plt.xlabel('Danceability', size=12)
plt.ylabel('Number of Tracks', size=12)
plt.title('Distribution showing danceable Tracks', size=12)
plt.xticks(size=12)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df['energy'], bins=30, kde=False)
plt.xlabel('Energy', size=12)
plt.ylabel('Number of Tracks', size=12)
plt.title('Distribution showing energetic Tracks', size=12)
plt.xticks(size=12)
plt.show()

# %%
df.isna().sum()
# Out:
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
import pandas as pd

# Assuming df is your DataFrame and 'key' is the column with 11 categories
df = pd.get_dummies(df, columns=['key'], prefix='key')
df
# Out:
#                       track_id                 artists  \
# 0       5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1       4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2       1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3       6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4       5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...                        ...                     ...
# 113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# ...

# %%
x=df[['danceability', 'energy', 'key_1','key_2','key_3','key_4','key_5','key_6','key_7','key_8','key_9','key_10','key_11','loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo','time_signature']].corr()
plt.figure(figsize=(16, 15))

sns.heatmap(x, annot=True,fmt=".2f",cmap='coolwarm')
# Out:
# <Axes: >

# %%
df=df.drop(['acousticness','loudness'],axis=1)

# %% [markdown]
# NORMALIZING DATA

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[['danceability', 'energy', 'speechiness',  'instrumentalness', 'liveness', 'valence', 'tempo']] = scaler.fit_transform(df[['danceability', 'energy',  'speechiness',  'instrumentalness', 'liveness', 'valence', 'tempo']])

# %%
df.track_id.value_counts()
# Out:
# track_id
# 6S3JlDAGk3uu3NtZbPnuhS    9
# 2kkvB3RNRzwjFdGhaUA0tz    8
# 2Ey6v4Sekh3Z0RUSISRosD    8
# 5ZsAhuQ24mWHiduaxJqnhW    7
# 54zCdkbIALAnv8Ihi3XWlD    7
#                          ..
# 0S5LzudHxW15KfyTlCbpTI    1
# 55CmKRol1YivCpEFQ4EN0i    1
# 3vVRfT1O4KbAAhHTmzc5Sc    1
# 6RXI2dGFYwWNdi2fWthp2w    1
# 2IJftBfq7pJ43tfnOR0RB3    1
# Name: count, Length: 89741, dtype: int64

# %% [markdown]
# HANDLING NON NUMERIC DATA

# %%
df.drop_duplicates(subset='track_id', inplace=True)

# %%
df.track_id.value_counts()
# Out:
# track_id
# 2hETkH7cOfqmz3LqZDHZf5    1
# 5SuOikwiRyPMVoIQDJUgSV    1
# 4qPNDBW1i3p13qLCt0Ki3A    1
# 1iJBSr7s7jYXzM8EGcbK5b    1
# 6lfxq3CG4xtTiEg7opyCyx    1
#                          ..
# 6xKeQgzfjixSUld14qUezm    1
# 4Yo0igmcoNyat1secaH0OD    1
# 2qLMf6TuEC3ruGJg4SMMN6    1
# 6CgNoAbFJ4Q4Id4EjtbXlC    1
# 3S0OXQeoh0w6AY8WQVckRW    1
# Name: count, Length: 89741, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['track_id'] = le.fit_transform(df['track_id'])

# %%
import torch.nn as nn
emdedding_data=32
track_vector  = nn.Embedding(len(df['track_id']), emdedding_data)

# %%
track_vector
# Out:
# Embedding(89741, 32)

# %%
df.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'mode',
#        'speechiness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'track_genre', 'key_0', 'key_1', 'key_2', 'key_3',
#        'key_4', 'key_5', 'key_6', 'key_7', 'key_8', 'key_9', 'key_10',
#        'key_11'],
#       dtype='object')

# %%
import re
df['album_name'] = df['album_name'].astype(str).str.lower().apply(lambda x: re.sub(r'[^a-zA-Z0-9\s]', '', x))
df['track_name'] = df['track_name'].astype(str).str.lower().apply(lambda x: re.sub(r'[^a-zA-Z0-9\s]', '', x))
df['track_genre'] = df['track_genre'].astype(str).str.lower().apply(lambda x: re.sub(r'[^a-zA-Z0-9\s]', '', x))

# %%
df.head(5)
# Out:
#    track_id                 artists  \
# 0     62846             Gen Hoshino
# 1     55668            Ben Woodward
# 2     19766  Ingrid Michaelson;ZAYN
# 3     77942            Kina Grannis
# 4     68242        Chord Overstreet
#
#                                           album_name  \
# 0                                             comedy
# 1                                     ghost acoustic
# 2                                     to begin again
# 3  crazy rich asians original motion picture soun...
# 4                                            hold on
#
#                   track_name  popularity  duration_ms  explicit  danceability  \
# 0                     comedy          73       230666     False      0.686294
# 1            ghost  acoustic          55       149610     False      0.426396
# 2             to begin again          57       210826     False      0.444670
# 3  cant help falling in love          71       201933     False      0.270051
# ...

# %%
df['artists']=df['artists'].astype(str).str.lower().apply((lambda x: [artist.strip() for artist in x.split(";")])) #artists are getting handled differently because some artists might have collaborated and we want to assign vectors accordingly
df.head(5)
# Out:
#    track_id                    artists  \
# 0     62846              [gen hoshino]
# 1     55668             [ben woodward]
# 2     19766  [ingrid michaelson, zayn]
# 3     77942             [kina grannis]
# 4     68242         [chord overstreet]
#
#                                           album_name  \
# 0                                             comedy
# 1                                     ghost acoustic
# 2                                     to begin again
# 3  crazy rich asians original motion picture soun...
# 4                                            hold on
#
#                   track_name  popularity  duration_ms  explicit  danceability  \
# 0                     comedy          73       230666     False      0.686294
# 1            ghost  acoustic          55       149610     False      0.426396
# 2             to begin again          57       210826     False      0.444670
# 3  cant help falling in love          71       201933     False      0.270051
# ...

# %%
unique_artists=df['artists'].explode().unique()
print(unique_artists)
# Out:
# ['gen hoshino' 'ben woodward' 'ingrid michaelson' ... 'molly skaggs'
#  'cuencos tibetanos sonidos relajantes' 'brock human']

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')
artist_encoded = {artist: model.encode(artist) for artist in unique_artists} #to know which embedding belongs to which artist
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# ...

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')
album_encoded = model.encode(df['album_name'].unique())

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')
track_encoded = model.encode(df['track_name'].unique())

# %%
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.decomposition import TruncatedSVD

mlb=MultiLabelBinarizer()
genre_encoded=mlb.fit_transform(df['track_genre'])

# %%
genre_to_embedding = dict(zip(df['track_genre'].unique(), genre_encoded))
df['genre_embedding'] = df['track_genre'].map(genre_to_embedding)

# For album embeddings
album_to_embedding = dict(zip(df['album_name'].unique(), album_encoded));
df['album_embedding'] = df['album_name'].map(album_to_embedding)

# For track embeddings
track_to_embedding = dict(zip(df['track_name'].unique(), track_encoded))
df['track_embedding'] = df['track_name'].map(track_to_embedding)

# %%
df.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'mode',
#        'speechiness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'track_genre', 'key_0', 'key_1', 'key_2', 'key_3',
#        'key_4', 'key_5', 'key_6', 'key_7', 'key_8', 'key_9', 'key_10',
#        'key_11', 'genre_embedding', 'album_embedding', 'track_embedding'],
#       dtype='object')

# %%
len(df['album_embedding'])
# Out:
# 89741

# %%
# Now use it with get_embeddings
import numpy as np
# For artist embeddings (handling collaborations)
def get_artist_embedding(artist_list):
    # Get embeddings for each artist in the list
    artist_embeds = [artist_encoded.get(artist) for artist in artist_list if artist in artist_encoded]

    # If no embeddings were found, return None or a default
    if not artist_embeds:
        return None

    # Average the embeddings
    return np.mean(artist_embeds, axis=0)

# Apply the function to get combined embeddings for artists
df['artist_embedding'] = df['artists'].apply(get_artist_embedding)# For album embeddings

# %%
#RECOMMENDER SYSTEM

# %%
df['artist_embedding'].head()
# Out:
# 0    [-0.07902416, 0.14263047, -0.048053544, -0.027...
# 1    [-0.004106492, 0.006048992, -0.022820406, -0.0...
# 2    [-0.08860522, 0.017602334, -0.058605812, 0.058...
# 3    [-0.071199015, 0.09318499, -0.0075394916, -0.1...
# 4    [-0.038158804, 0.006188726, -0.025508108, -0.0...
# Name: artist_embedding, dtype: object

# %%
combined_vectors = []
num_cols = ['danceability', 'energy', 'key_1', 'key_2', 'key_3', 'key_4', 'key_5', 'key_6', 'key_7', 'key_8', 'key_9', 'key_10', 'key_11', 'mode', 'speechiness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature']
embedding_cols = ['artist_embedding', 'album_embedding', 'track_embedding', 'genre_embedding']

# Loop through each row of the dataframe
for i in range(len(df)):
    # Collect numerical values from the row (converted to float)
    num_values = df.iloc[i][num_cols].values.astype(float)

    # Collect embedding vectors from the row
    emb_vectors = []
    for col in embedding_cols:
        emb_vectors.append(df.iloc[i][col])  # Append embedding for the current row

    # Combine numerical features and embedding vectors
    combined_features = np.concatenate([num_values] + emb_vectors)
    combined_vectors.append(combined_features)

# Stack the combined vectors into a matrix
combined_matrix = np.vstack(combined_vectors)

# %% [markdown]
# ANNOY BASED RECOMMENDER

# %%
# !pip install annoy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.5/647.5 kB 39.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for annoy: filename=annoy-1.17.3-cp312-cp312-linux_x86_64.whl size=549278 sha256=3dba328de03d67db9e6edbb15814616d59884d739a96a0f8fef3f37d0c9ab597
#   Stored in directory: /root/.cache/pip/wheels/db/b9/53/a3b2d1fe1743abadddec6aa541294b24fdbc39d7800bc57311
# Successfully built annoy
# ...

# %%
from scipy.spatial.distance import pdist, squareform
from annoy import AnnoyIndex
import numpy as np
embedding_dim=combined_matrix.shape[1]
previous_track=[]
current_track=[]
annoy_index = AnnoyIndex(embedding_dim, 'angular')
for i in range(len(df)):
    annoy_index.add_item(i, combined_matrix[i])
annoy_index.build(10)
def get_recommended_tracks(current_track_index, k=5):
    print("Fetchingg")
    nearest_neighbors = annoy_index.get_nns_by_item(current_track_index, k)
    neighbor_embeddings = np.array([combined_matrix[i] for i in nearest_neighbors])
    pairwise_distances = pdist(neighbor_embeddings, metric='cosine')  # Using cosine distance (angular)

    # Diversity score as the average of the pairwise distances
    diversity_score = pairwise_distances.mean()

    print(f"Diversity Score for Track {current_track_index}: {diversity_score}")

    previous_track.extend(nearest_neighbors)
    current_track=nearest_neighbors[0]
    return nearest_neighbors

# %%
def get_recommended_tracks_info(current_track_index, k=5):
    nearest_neighbors = annoy_index.get_nns_by_item(current_track_index, k)


    recommended_tracks_info = df.iloc[nearest_neighbors]

    for idx in nearest_neighbors:
        track_info = df.iloc[idx]
        print(f"Recommended Track Index: {idx}")
        print(f"Album: {track_info['album_name']}")
        print(f"Genre: {track_info['track_genre']}")
        print(f"Artist: {track_info['artists']}")
        print("-" * 30)

    return recommended_tracks_info

# %% [markdown]
# RL BASED RECOMMENDER

# %%
state = {
    'previous_track': previous_track,
    'current_track': current_track
}

# %%
import random
from annoy import AnnoyIndex

class MusicRecommenderEnv:
    def __init__(self, annoy_index, combined_matrix, epsilon=0.1):
        self.annoy_index = annoy_index
        self.combined_matrix = combined_matrix
        self.epsilon = epsilon
        self.previous_tracks = []
        self.current_track = None
        self.max_distance = self.calculate_max_distance()
        self.threshold = self.max_distance * 0.3


    def calculate_max_distance(self):
          max_distance = -1
          for i in range(len(self.combined_matrix)):
              for j in range(i + 1, len(self.combined_matrix)):
                  distance = self.annoy_index.get_distance(i, j)
                  max_distance = max(max_distance, distance)
          return max_distance
    def reset(self):
        self.previous_tracks = []
        self.current_track = random.choice(range(len(self.combined_matrix)))
        return {
            'previous_tracks': self.previous_tracks,
            'current_track': self.current_track
        }
    def step(self, action, calculate_reward):
        reward = calculate_reward(self.previous_tracks, self.current_track, action, self.threshold, self.annoy_index)

        self.previous_tracks.append(self.current_track)
        self.current_track = action

        return {
            'previous_tracks': self.previous_tracks,
            'current_track': self.current_track
        }, reward


    def start_action(self, state, epsilon=None):
      if epsilon is None:
          epsilon = self.epsilon

      recommended_tracks = state['previous_tracks']

      # If no previous tracks, randomly select from full dataset
      if not recommended_tracks:
          return random.choice(range(len(self.combined_matrix)))

      if random.random() < epsilon:
          action = random.choice(recommended_tracks)
      else:
          action = recommended_tracks[0]

      return action

# %%
def calculate_reward(previous_tracks, current_track, action, threshold, annoy_index):
    if not previous_tracks:
        return 1

    distances = [annoy_index.get_distance(prev, action) for prev in previous_tracks]
    avg_distance = sum(distances) / len(distances)

    lower_bound = threshold * 0.5
    upper_bound = threshold * 1.2

    if lower_bound <= avg_distance <= upper_bound:
        return 1
    else:
        return 0


rl_recommended_tracks=[]

env = MusicRecommenderEnv(annoy_index, combined_matrix, epsilon=0.1)

state = env.reset()

for episode in range(5):
    print(f"Episode {episode + 1}:")

    action = env.start_action(state)
    print(f"Recommended track: {action}")

    rl_recommended_tracks.append(action)

    next_state, reward = env.step(action, calculate_reward)
    print(f"Reward: {reward}")

    state = next_state
# Out:
# Episode 1:
# Recommended track: 23683
# Reward: 1
# Episode 2:
# Recommended track: 8606
# Reward: 0
# Episode 3:
# Recommended track: 8606
# Reward: 1
# Episode 4:
# Recommended track: 8606
# Reward: 0
# Episode 5:
# Recommended track: 8606
# Reward: 0

# %%
base_info=df.iloc[state['previous_tracks']]
print(f"Base Track")
print(f"Album: {base_info['album_name']}")
print(f"Genre: {base_info['track_genre']}")
print(f"Artist: {base_info['artists']}")
track_info = df.iloc[action]
print(f"Recommended track:")
print(f"Album: {track_info['album_name']}")
print(f"Genre: {track_info['track_genre']}")
print(f"Artist: {track_info['artists']}")
# Out:
# Base Track
# Album: 9293     legio urbana
# 25062    pov its 2020
# 9293     legio urbana
# 9293     legio urbana
# 9293     legio urbana
# Name: album_name, dtype: object
# Genre: 9293     brazil
# 25062     disco
# 9293     brazil
# 9293     brazil
# 9293     brazil
# Name: track_genre, dtype: object
# Artist: 9293                 [legião urbana]
# 25062    [martin solveig, roy woods]
# 9293                 [legião urbana]
# 9293                 [legião urbana]
# 9293                 [legião urbana]
# Name: artists, dtype: object
# Recommended track:
# Album: legio urbana
# Genre: brazil
# Artist: ['legião urbana']

# %% [markdown]
# COMPARING ANNOY AND ANNOY WITH RL

# %%
current_index=state['current_track']
annoy_recs = get_recommended_tracks(current_index, k=5)
# Out:
# Fetchingg
# Diversity Score for Track 8606: 0.07065061823553158

# %%
def diversity_score(previous_tracks, current_track, annoy_index):
    if not previous_tracks:
        return 0.0  # No previous tracks to compare with

    distances = [
        annoy_index.get_distance(prev, current_track) for prev in previous_tracks
    ]
    return sum(distances) / len(distances)

# %%
rl_div = diversity_score(state['previous_tracks'], action, annoy_index)
print(f"Diversity Score for current recommended track: {rl_div:.4f}")
# Out:
# Diversity Score for current recommended track: 0.1058

# %%
import seaborn as sns

def plot_distance_heatmap(recommended_indices):
    # Extract embeddings for recommended tracks
    embeddings = np.array([combined_matrix[i] for i in recommended_indices])
    pairwise_cosine = squareform(pdist(embeddings, metric='cosine'))

    # Plot heatmap
    plt.figure(figsize=(8, 6))
    sns.heatmap(pairwise_cosine, annot=True, cmap='viridis', xticklabels=recommended_indices, yticklabels=recommended_indices)
    plt.title("Cosine Distance Heatmap of Recommended Tracks")
    plt.xlabel("Track Index")
    plt.ylabel("Track Index")
    plt.show()

# %%
recommended = get_recommended_tracks(current_track_index=10, k=5)

# Now you can plot
plot_distance_heatmap(recommended)
# Out:
# Fetchingg
# Diversity Score for Track 10: 0.05341836504436043

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

def plot_episode_tracks(embedding_matrix, previous_tracks, current_track, df):
    pca = PCA(n_components=2)
    reduced = pca.fit_transform(embedding_matrix)

    plt.figure(figsize=(10, 6))

    # Plot all tracks
    plt.scatter(reduced[:, 0], reduced[:, 1], color='lightgray', alpha=0.5, label='All Tracks')

    # Plot previous tracks
    if previous_tracks:
        prev_coords = reduced[previous_tracks]
        plt.scatter(prev_coords[:, 0], prev_coords[:, 1], color='blue', s=60, label='Previous Tracks')

    # Plot current recommended track
    plt.scatter(reduced[current_track, 0], reduced[current_track, 1], color='red', s=80, label='Recommended Track')

    # Optional: label the current track
    track_name = df.iloc[current_track]['track_name']
    plt.annotate(track_name, (reduced[current_track, 0], reduced[current_track, 1]), fontsize=9)

    plt.title("Track Recommendation Visualization (PCA)")
    plt.legend()
    plt.grid(True)
    plt.show()

plot_episode_tracks(combined_matrix, state['previous_tracks'], state['current_track'], df)

# %%
def plot_distance_distribution(recommended_tracks, annoy_index):
    distances = []
    for i in range(len(recommended_tracks) - 1):
        for j in range(i + 1, len(recommended_tracks)):
            distance = annoy_index.get_distance(recommended_tracks[i], recommended_tracks[j])
            distances.append(distance)

    plt.figure(figsize=(8, 5))
    plt.hist(distances, bins=30, color='lightblue', edgecolor='black')
    plt.title("Distance Distribution Between Recommended Tracks")
    plt.xlabel("Cosine Distance")
    plt.ylabel("Frequency")
    plt.grid(True)
    plt.show()

# %%
plot_distance_distribution(rl_recommended_tracks, annoy_index)

# %%
def plot_exploration_vs_exploitation(epsilon, total_steps):
    exploration_count = int(total_steps * epsilon)
    exploitation_count = total_steps - exploration_count

    plt.figure(figsize=(6, 4))
    plt.bar(['Exploration', 'Exploitation'], [exploration_count, exploitation_count], color=['lightblue', 'lightgreen'])
    plt.title(f"Exploration vs Exploitation (epsilon={epsilon})")
    plt.ylabel("Count")
    plt.show()

# %%
# Reset the environment
env = MusicRecommenderEnv(annoy_index, combined_matrix, epsilon=0.1)

state = env.reset()

# List to store all recommended tracks over episodes
rl_recommended_tracks = []

# Variables to track exploration vs exploitation
exploration_count = 0
exploitation_count = 0

# Simulate a few episodes
for episode in range(5):
    print(f"Episode {episode + 1}:")

    # Start action using epsilon-greedy
    action = env.start_action(state)

    # Track exploration vs exploitation
    if random.random() < env.epsilon:
        exploration_count += 1
    else:
        exploitation_count += 1

    print(f"Recommended track: {action}")

    rl_recommended_tracks.append(action)

    # Get the next state and reward
    next_state, reward = env.step(action, calculate_reward)
    print(f"Reward: {reward}")

    state = next_state

    # Print info for the base track and recommended track
    base_info = df.iloc[state['previous_tracks']]
    print(f"Base Track")
    print(f"Album: {base_info['album_name']}")
    print(f"Genre: {base_info['track_genre']}")
    print(f"Artist: {base_info['artists']}")

    track_info = df.iloc[action]
    print(f"Recommended track:")
    print(f"Album: {track_info['album_name']}")
    print(f"Genre: {track_info['track_genre']}")
    print(f"Artist: {track_info['artists']}")

# After the loop, plot Exploration vs Exploitation
plot_exploration_vs_exploitation(env.epsilon, exploration_count + exploitation_count)
# Out:
# Episode 1:
# Recommended track: 58838
# Reward: 1
# Base Track
# Album: 15580    modern breakups
# Name: album_name, dtype: object
# Genre: 15580    chill
# Name: track_genre, dtype: object
# Artist: 15580    [slchld]
# Name: artists, dtype: object
# Recommended track:
# Album: ayo
# Genre: malay
# Artist: ['thirumali', 'parimal shais']
# Episode 2:
# Recommended track: 14704
# Reward: 0
# Base Track
# Album: 15580    modern breakups
# 69807                ayo
# Name: album_name, dtype: object
# Genre: 15580    chill
# 69807    malay
# Name: track_genre, dtype: object
# Artist: 15580                      [slchld]
# 69807    [thirumali, parimal shais]
# Name: artists, dtype: object
# Recommended track:
# Album: modern breakups
# Genre: chill
# Artist: ['slchld']
# Episode 3:
# Recommended track: 58838
# Reward: 1
# Base Track
# Album: 15580    modern breakups
# 69807                ayo
# 15580    modern breakups
# Name: album_name, dtype: object
# Genre: 15580    chill
# ...
